# %%
import pandas as pd
import numpy as np
from PIL import Image
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
df_word = pd.read_csv('word.csv')
df_word
# Out:
#           word_A     A        word_B       B           word_C       C  \
# 0      invention  4055  premalignant  4986.0            slags  3000.0
# 1        relates  2646      national  4921.0         laterite  2989.0
# 2     comprising  2103       aramide  4912.0  heteroarylalkyl  2970.0
# 3        present  1948     rheumatic  4901.0          ferrous  2963.0
# 4            one  1926           hcg  4856.0            sieve  2961.0
# ..           ...   ...           ...     ...              ...     ...
# 191        metal    62    fretshaped     1.0            bogie    15.0
# 192         heat    53           NaN     NaN       assessment    14.0
# 193     reaction    43           NaN     NaN            aroma    12.0
# 194  information    27           NaN     NaN          affixed     9.0
# 195       stream    16           NaN     NaN              NaN     NaN
#
#           word_D     D       word_E       E      word_F     F       word_G  \
# ...

# %%
for ele in ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']:
    dict = {}
    word = df_word['word_'+ele].tolist()
    count = df_word[ele].tolist()
    for i in range(len(word)):
        dict[word[i]]=count[i]

    wc = WordCloud(background_color='white', max_words=200, contour_width=0, colormap='ocean',
                  width=800, height=400, min_font_size=10, font_path='Facile Sans.ttf').generate_from_frequencies(dict)
    wc.to_file('word_cloud_'+ele+'.png')
